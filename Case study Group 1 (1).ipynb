# %% [markdown]
# # Group 1 - Haritha CM, Ardra Jose, Nafeela Pary, Adwaid sp, Thabsheera

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hotel=pd.read_csv(r'C:\Users\paryn\Downloads\hotel-tips.csv')

# %%
hotel.head()
# Out:
#    Unknown  bill_id  total_bill   tip     sex smoker  day    time  size
# 0      110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1      111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2      112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3      113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4      114    10115       24.59  3.61  Female     No  Sun  Dinner     4

# %%
hotel.shape
# Out:
# (244, 9)

# %%
hotel.columns
# Out:
# Index(['Unknown', 'bill_id', 'total_bill', 'tip', 'sex', 'smoker', 'day',
#        'time', 'size'],
#       dtype='object')

# %%
hotel.describe()
# Out:
#           Unknown       bill_id  total_bill         tip        size
# count  244.000000    244.000000  244.000000  244.000000  244.000000
# mean   231.500000  10232.500000   19.785943    2.998279    2.569672
# std     70.580923     70.580923    8.902412    1.383638    0.951100
# min    110.000000  10111.000000    3.070000    1.000000    1.000000
# 25%    170.750000  10171.750000   13.347500    2.000000    2.000000
# 50%    231.500000  10232.500000   17.795000    2.900000    2.000000
# 75%    292.250000  10293.250000   24.127500    3.562500    3.000000
# max    353.000000  10354.000000   50.810000   10.000000    6.000000

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unknown     244 non-null    int64
#  1   bill_id     244 non-null    int64
#  2   total_bill  244 non-null    float64
#  3   tip         244 non-null    float64
#  4   sex         244 non-null    object
#  5   smoker      244 non-null    object
#  6   day         244 non-null    object
#  7   time        244 non-null    object
#  8   size        244 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 17.3+ KB

# %%
hotel['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
hotel['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sex=['Male','Female']
plt.pie(hotel['sex'].value_counts(),labels=hotel['sex'].value_counts())
plt.legend(sex)
plt.show()

# %%
sns.countplot(x=hotel.time)
plt.show()

# %%
plt.bar(hotel['day'],hotel['total_bill'])
plt.xlabel('Day')
plt.ylabel('Total bill')
plt.show()

# %%
plt.scatter(hotel['total_bill'],hotel['tip'])
plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.show()

# %%
plt.bar(hotel['sex'],hotel['total_bill'])
plt.title('Sex Vs Total bill')
plt.xlabel('Sex')
plt.ylabel('Total bill')
plt.show()

# %%
plt.hist(hotel['total_bill'])
plt.title('Distribution of total bill')
plt.show()

# %%
plt.hist(hotel['tip'])
plt.title('Distribution of tip')
plt.show()

# %%
plt.boxplot(hotel['tip']) 
plt.show()

# %%
plt.boxplot(hotel['total_bill']) 
plt.show()

# %%
smoking=['Smoker','Non-Smoker']
num=[93,151]
plt.pie(num,labels=smoking,autopct="%1.1f%%")
plt.show()

# %%
sns.pairplot(hotel)

# %%
hotel_col=hotel[['total_bill','tip']]
sns.heatmap(hotel_col.corr(),annot=True)
# Out:
# <Axes: >

# %%
female_df=hotel[hotel['sex']=='Female']
female_df
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# 11       121    10122       35.26  5.00  Female     No   Sun  Dinner     4
# 14       124    10125       14.83  3.02  Female     No   Sun  Dinner     2
# 16       126    10127       10.33  1.67  Female     No   Sun  Dinner     3
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 226      336    10337       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229      339    10340       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238      348    10349       35.83  4.67  Female     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 9 columns]

# %%
#Finding number of smokers for each sex
smoker_df=hotel[hotel['smoker']=='Yes']
sns.countplot(x=smoker_df.sex)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#Time of more female customers
sns.countplot(x=female_df.time)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='size', data=hotel)
# Out:
# <Axes: xlabel='size', ylabel='count'>
